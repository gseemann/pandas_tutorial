# %% [markdown]
# # Beginner's Guide to using pandas

# %%
#import the necessary libraries
import pandas as pd

# %% [markdown]
# ## We will begin by downloading a sample dataset

# %%
#use the pd.read_csv to get our file uploaded
df = pd.read_csv('toy_dataset.csv')

# %%
df.Number = df.Number -1

# %%
df.rename(columns={'Number':'index'}, inplace=True)
df.set_index('index', inplace=True)
df.head()
# Out:
#          City Gender  Age   Income Illness
# index
# 0      Dallas   Male   41  40367.0      No
# 1      Dallas   Male   54  45084.0      No
# 2      Dallas   Male   42  52483.0      No
# 3      Dallas   Male   40  40941.0      No
# 4      Dallas   Male   46  50289.0      No

# %%
df['City']=='Dallas'
# Out:
# index
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 149995    False
# 149996    False
# 149997    False
# 149998    False
# 149999    False
# Name: City, Length: 150000, dtype: bool

# %%
df['City']
# Out:
# index
# 0         Dallas
# 1         Dallas
# 2         Dallas
# 3         Dallas
# 4         Dallas
#            ...
# 149995    Austin
# 149996    Austin
# 149997    Austin
# 149998    Austin
# 149999    Austin
# Name: City, Length: 150000, dtype: object

# %% [markdown]
# ## Using [ ] operator

# %%
df[['City','Age']]
# Out:
#           City  Age
# index
# 0       Dallas   41
# 1       Dallas   54
# 2       Dallas   42
# 3       Dallas   40
# 4       Dallas   46
# ...        ...  ...
# 149995  Austin   48
# 149996  Austin   25
# 149997  Austin   26
# 149998  Austin   25
# 149999  Austin   37
#
# [150000 rows x 2 columns]

# %%
df[df['City']=='Dallas']
# Out:
#          City  Gender  Age   Income Illness
# index
# 0      Dallas    Male   41  40367.0      No
# 1      Dallas    Male   54  45084.0      No
# 2      Dallas    Male   42  52483.0      No
# 3      Dallas    Male   40  40941.0      No
# 4      Dallas    Male   46  50289.0      No
# ...       ...     ...  ...      ...     ...
# 19702  Dallas  Female   59  30021.0      No
# 19703  Dallas    Male   33  34643.0      No
# 19704  Dallas    Male   33  53190.0      No
# 19705  Dallas    Male   37  54265.0      No
# 19706  Dallas    Male   59  51265.0      No
#
# [19707 rows x 5 columns]

# %%
df[df['Age']>=45]    #you can also use other comparisons
# Out:
#           City  Gender  Age   Income Illness
# index
# 1       Dallas    Male   54  45084.0      No
# 4       Dallas    Male   46  50289.0      No
# 8       Dallas    Male   51  68667.0      No
# 10      Dallas  Female   48  41524.0     Yes
# 11      Dallas    Male   47  54777.0      No
# ...        ...     ...  ...      ...     ...
# 149987  Austin  Female   55  62501.0      No
# 149989  Austin    Male   52  83688.0      No
# 149991  Austin    Male   51  97510.0      No
# 149993  Austin    Male   64  89906.0      No
# 149995  Austin    Male   48  93669.0      No
#
# [76479 rows x 5 columns]

# %%
#note both conditions must be inclosed in brackets
df[(df['Age']>=45) &(df['City']=='Dallas')]
# Out:
#          City  Gender  Age   Income Illness
# index
# 1      Dallas    Male   54  45084.0      No
# 4      Dallas    Male   46  50289.0      No
# 8      Dallas    Male   51  68667.0      No
# 10     Dallas  Female   48  41524.0     Yes
# 11     Dallas    Male   47  54777.0      No
# ...       ...     ...  ...      ...     ...
# 19698  Dallas    Male   58  47757.0      No
# 19700  Dallas    Male   58  44083.0      No
# 19701  Dallas  Female   48  46132.0      No
# 19702  Dallas  Female   59  30021.0      No
# 19706  Dallas    Male   59  51265.0      No
#
# [10076 rows x 5 columns]

# %% [markdown]
# ## Using .loc operator

# %%
df.loc[0,'Gender']
# Out:
# 'Male'

# %%
df.loc[1:4,'Gender':'Income']
# Out:
#       Gender  Age   Income
# index
# 1       Male   54  45084.0
# 2       Male   42  52483.0
# 3       Male   40  40941.0
# 4       Male   46  50289.0

# %%
df.loc[:,'Gender']
# Out:
# index
# 0           Male
# 1           Male
# 2           Male
# 3           Male
# 4           Male
#            ...
# 149995      Male
# 149996      Male
# 149997      Male
# 149998      Male
# 149999    Female
# Name: Gender, Length: 150000, dtype: object

# %%
df.loc[1:4,:]
# Out:
#          City Gender  Age   Income Illness
# index
# 1      Dallas   Male   54  45084.0      No
# 2      Dallas   Male   42  52483.0      No
# 3      Dallas   Male   40  40941.0      No
# 4      Dallas   Male   46  50289.0      No

# %%
df.loc[:,'Gender':'Income']   #return all rows and columns Gender through Income
# Out:
#         Gender  Age    Income
# index
# 0         Male   41   40367.0
# 1         Male   54   45084.0
# 2         Male   42   52483.0
# 3         Male   40   40941.0
# 4         Male   46   50289.0
# ...        ...  ...       ...
# 149995    Male   48   93669.0
# 149996    Male   25   96748.0
# 149997    Male   26  111885.0
# 149998    Male   25  111878.0
# 149999  Female   37   87251.0
#
# [150000 rows x 3 columns]

# %%
df.loc[:10,:]     #return start through index 10 and all columns
# Out:
#          City  Gender  Age   Income Illness
# index
# 0      Dallas    Male   41  40367.0      No
# 1      Dallas    Male   54  45084.0      No
# 2      Dallas    Male   42  52483.0      No
# 3      Dallas    Male   40  40941.0      No
# 4      Dallas    Male   46  50289.0      No
# 5      Dallas  Female   36  50786.0      No
# 6      Dallas  Female   32  33155.0      No
# 7      Dallas    Male   39  30914.0      No
# 8      Dallas    Male   51  68667.0      No
# 9      Dallas  Female   30  50082.0      No
# 10     Dallas  Female   48  41524.0     Yes

# %%
#we can also select specific rows and columns
df.loc[[0,5,27,539], ['Income', 'Illness']]
# Out:
#         Income Illness
# index
# 0      40367.0      No
# 5      50786.0      No
# 27     61704.0      No
# 539    44490.0      No

# %% [markdown]
# ## Using .iloc

# %%
df = pd.read_csv('Islander_data.csv')
df.set_index(['first_name', 'last_name'], inplace=True)
df.head()
# Out:
#                       age Happy_Sad_group  Dosage Drug  Mem_Score_Before  \
# first_name last_name
# Bastian    Carrasco    25               H       1    A              63.5
# Evan       Carrasco    52               S       1    A              41.6
# Florencia  Carrasco    29               H       1    A              59.7
# Holly      Carrasco    50               S       1    A              51.7
# Justin     Carrasco    52               H       1    A              47.0
#
#                       Mem_Score_After  Diff
# first_name last_name
# Bastian    Carrasco              61.2  -2.3
# Evan       Carrasco              40.7  -0.9
# Florencia  Carrasco              55.1  -4.6
# Holly      Carrasco              51.2  -0.5
# Justin     Carrasco              47.1   0.1

# %%
df.head(10)
# Out:
#                       age Happy_Sad_group  Dosage Drug  Mem_Score_Before  \
# first_name last_name
# Bastian    Carrasco    25               H       1    A              63.5
# Evan       Carrasco    52               S       1    A              41.6
# Florencia  Carrasco    29               H       1    A              59.7
# Holly      Carrasco    50               S       1    A              51.7
# Justin     Carrasco    52               H       1    A              47.0
# Liam       Carrasco    37               S       1    A              66.4
# Ava        Durand      35               S       1    A              44.1
# Jamie      Durand      38               H       1    A              76.3
# Josefa     Durand      29               H       1    A              56.2
# Mark       Durand      36               S       1    A              54.8
#
#                       Mem_Score_After  Diff
# first_name last_name
# Bastian    Carrasco              61.2  -2.3
# ...

# %%
df.shape
# Out:
# (198, 7)

# %%
#lets start by making the income 
df.set_index(['City', 'Income'])
# Out:
#                  Gender  Age Illness
# City   Income
# Dallas 40367.0     Male   41      No
#        45084.0     Male   54      No
#        52483.0     Male   42      No
#        40941.0     Male   40      No
#        50289.0     Male   46      No
# ...                 ...  ...     ...
# Austin 93669.0     Male   48      No
#        96748.0     Male   25      No
#        111885.0    Male   26      No
#        111878.0    Male   25      No
#        87251.0   Female   37      No
#
# [150000 rows x 3 columns]

# %%
df

# %%
df.iloc[0,'Gender']
